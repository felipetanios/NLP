# %% [markdown]
# # Starting Lyrics Processing

# %% [markdown]
# ###### Importing all libraries needed

# %%
import numpy as np
import nltk
from sklearn.preprocessing import normalize
from sklearn import preprocessing
from sklearn.cross_validation import StratifiedKFold
from sklearn.cross_validation import ShuffleSplit
from sklearn.grid_search import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
import copy
from scipy.stats import friedmanchisquare as friedman
from scipy.stats import wilcoxon as wilcoxon
from scipy.stats import ttest_ind as ttest
from scipy.stats import ttest_ind_from_stats as ttest2
from scipy.stats import f_oneway as f_oneway
from matplotlib import pyplot as plt
import csv
import os

# %% [markdown]
# ###### getting all the lyrics

# %%
tracks_names = []
tracks_lyrics = []

for root, dirs, files in os.walk("."):
    for f in files:
        if f[-3:] == "txt":
            tracks_names.append(f)
            tracks_path = os.path.join(root, f)
            track_single_lyric =  open (tracks_path, 'r')
            track_single_lyric
            tracks_lyrics.append(track_single_lyric.read())

print tracks_lyrics
# Out:
# ['\nMadalena O meu peito percebeu Que o mar \xc3\xa9 uma gota Comparado ao pranto meu.\nFique certa Quando o nosso amor desperta Logo o sol se desespera E se esconde l\xc3\xa1 na serra.\nMadalena O que \xc3\xa9 meu n\xc3\xa3o se divide Nem t\xc3\xa3o pouco se admite Quem do nosso amor duvide.\nAt\xc3\xa9 a lua se arrisca num palpite Que o nosso amor existe Forte ou fraco alegre ou triste. ', '\nDepois de trabalhar toda a semana Meu s\xc3\xa1bado n\xc3\xa3o vou desperdi\xc3\xa7ar J\xc3\xa1 fiz o meu programa pra esta noite E sei por onde come\xc3\xa7ar\nUm bom lugar para encontrar: Copacabana Pr\xc3\xa1 passear \xc3\xa0 beira-mar: Copacabana Depois num bar \xc3\xa0 meia-luz: Copacabana Eu esperei por essa noite uma semana\nUm bom jantar depois de dan\xc3\xa7ar: Copacabana Um s\xc3\xb3 lugar para se amar: Copacabana A noite passa t\xc3\xa3o depressa, mas vou voltar se pra semana Eu encontrar um novo amor: Copacabana ', '\nPai, afasta de mim esse c\xc3\xa1lice Pai, afasta de mim esse c\xc3\xa1lice Pai, afasta de mim esse c\xc3\xa1lice De vinho tinto de sangue\nPai, afasta de mim esse c\xc3\xa1lice Pai, afasta de mim esse c\xc3\xa1lice Pai, afasta de mim esse c\xc3\xa1lice De vinho tinto de sangue\nComo beber dessa bebida amarga Tragar a dor, engolir a labuta Mesmo calada a boca, resta o peito Sil\xc3\xaancio na cidade n\xc3\xa3o se escuta De que me vale ser filho da santa Melhor seria ser filho da outra Outra realidade menos morta Tanta mentira, tanta for\xc3\xa7a bruta\nPai, afasta de mim esse c\xc3\xa1lice Pai, afasta de mim esse c\xc3\xa1lice Pai, afasta de mim esse c\xc3\xa1l